# %%
pets = read.csv("Pet Counts Per Region Per Capita (2013).csv")
typeof(pets)
is.data.frame(pets)
pets
# Out:
# [1] "list"
# [1] TRUE
#    X  Breed                          Taranaki_Per_Capita Tasman_Per_Capita
# 1   1 All cross breeds               5.966015e-02        0.1005429020
# 2   2 All pure and cross breeds      1.620883e-01        0.2315604191
# 3   3 All pure breeds                1.024281e-01        0.1310175171
# 4   4 Beagle                         4.920049e-04        0.0007422488
# 5   5 Bichon Frise                   2.614915e-03        0.0021419180
# 6   6 Boxer                          1.430459e-03        0.0016541545
# 7   7 Brazilian Fila                 0.000000e+00        0.0000000000
# 8   8 Cattle, Australian             1.293791e-03        0.0033719303
# 9   9 Chihuahua, Long Coat           1.120678e-03        0.0007422488
# 10 10 Chihuahua, Smooth Coat         9.202314e-04        0.0009967341
# 11 11 Collie, Bearded                8.200082e-04        0.0021419180
# 12 12 Collie, Border                 6.140950e-03        0.0140178988
# ...

# %%
pets$X = NULL

# %%
epic_pets = t(pets)

is.data.frame(epic_pets)
epic_pets
# Out:
# [1] FALSE
#                               [,1]             [,2]
# Breed                         All cross breeds All pure and cross breeds
# Taranaki_Per_Capita           5.966015e-02     1.620883e-01
# Tasman_Per_Capita             0.1005429020     0.2315604191
# Waikato_Per_Capita            6.056131e-02     1.539232e-01
# Wellington_Per_Capita         4.655599e-02     1.058347e-01
# West_Coast_Per_Capita         8.408824e-02     1.989180e-01
# Manawatu_Whanganui_Per_Capita 2.693696e-02     1.026422e-01
# Marlborough_Per_Capita        0.0483692648     0.1202782384
# Nelson_Per_Capita             5.799255e-02     1.157913e-01
# Otago_Per_Capita              0.0636588853     0.1835881653
# Southland_Per_Capita          8.033897e-02     2.630327e-01
# Northland_Per_Capita          0.0616314638     0.1617224376
# Auckland_Per_Capita           2.825757e-02     7.493766e-02
# Bay_Of_Plenty_Per_Capita      7.230284e-02     1.455495e-01
# ...

# %%
#install.packages("janitor")
library(janitor)

# %%
epic_pets = row_to_names(epic_pets,1)
epic_pets
# Out:
#                               All cross breeds All pure and cross breeds
# Taranaki_Per_Capita           5.966015e-02     1.620883e-01
# Tasman_Per_Capita             0.1005429020     0.2315604191
# Waikato_Per_Capita            6.056131e-02     1.539232e-01
# Wellington_Per_Capita         4.655599e-02     1.058347e-01
# West_Coast_Per_Capita         8.408824e-02     1.989180e-01
# Manawatu_Whanganui_Per_Capita 2.693696e-02     1.026422e-01
# Marlborough_Per_Capita        0.0483692648     0.1202782384
# Nelson_Per_Capita             5.799255e-02     1.157913e-01
# Otago_Per_Capita              0.0636588853     0.1835881653
# Southland_Per_Capita          8.033897e-02     2.630327e-01
# Northland_Per_Capita          0.0616314638     0.1617224376
# Auckland_Per_Capita           2.825757e-02     7.493766e-02
# Bay_Of_Plenty_Per_Capita      7.230284e-02     1.455495e-01
# Canterbury_Per_Capita         5.996670e-02     1.700687e-01
# ...

# %%
epic_pets$Huntaway
# Out:
#           Taranaki_Per_Capita             Tasman_Per_Capita
#                  8.172748e-03                  0.0101582050
#            Waikato_Per_Capita         Wellington_Per_Capita
#                  8.957887e-03                  3.621647e-03
#         West_Coast_Per_Capita Manawatu_Whanganui_Per_Capita
#                  7.003858e-03                  1.421342e-02
#        Marlborough_Per_Capita             Nelson_Per_Capita
#                  0.0072899392                  1.162866e-03
#              Otago_Per_Capita          Southland_Per_Capita
#                  0.0100459462                  2.722247e-02
#          Northland_Per_Capita           Auckland_Per_Capita
#                  0.0109036732                  9.176645e-04
#      Bay_Of_Plenty_Per_Capita         Canterbury_Per_Capita
#                  2.875597e-03                  7.438840e-03
#          Gisbourne_Per_Capita         Hawkes_Bay_Per_Capita
#                  4.735070e-02                  1.751216e-02
# ...

# %%
epic_pets$`Brazilian Fila` = NULL
epic_pets$`Perro de Presa Canario` = NULL
epic_pets$`Tosa, Japanese` = NULL

# %%
epic_pets$`Chihuahua, Long Coat` + epic_pets$`Chihuahua, Smooth Coat`
# Out:
# Warning message in Ops.factor(epic_pets$`Chihuahua, Long Coat`, epic_pets$`Chihuahua, Smooth Coat`):
# “‘+’ not meaningful for factors”
#  [1] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA

# %%
library(hablar)
# Out:
# Attaching package: ‘hablar’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     na_if

# %%
?retype
# Out:
# retype                 package:hablar                  R Documentation
#
# s
#
# n:
#
#      ‘retype’ transforms all elements into simple classes. The simple
#      classes are date, numeric and character. By transforming all
#      elements to these classes no information is lost, while
#      simplifying the object. See details below for more information or
#      type ‘vignette("retype")’ in the console.
#
# e:
#
#      retype(.x, ...)
#
#      ## Default S3 method:
#      retype(.x, ...)
#
#      ## S3 method for class 'logical'
#      retype(.x, ...)
#
#      ## S3 method for class 'integer'
#      retype(.x, ...)
#
#      ## S3 method for class 'Date'
#      retype(.x, ...)
#
#      ## S3 method for class 'POSIXct'
#      retype(.x, ...)
#
#      ## S3 method for class 'numeric'
#      retype(.x, ...)
#
#      ## S3 method for class 'list'
#      retype(.x, ...)
#
#      ## S3 method for class 'data.frame'
#      retype(.x, ...)
#
# s:
#
#       .x: vector or data.frame
#
# ...

# %%
even_more_epic_dogs <- epic_pets %>%
                        retype()

# %%
even_more_epic_dogs
# Out:
#    All cross breeds All pure and cross breeds All pure breeds Beagle
# 1  0.05966015       0.16208830                0.10242810      0.0004920049
# 2  0.10054290       0.23156042                0.13101752      0.0007422488
# 3  0.06056131       0.15392320                0.09336192      0.0005597117
# 4  0.04655599       0.10583470                0.05927867      0.0005838004
# 5  0.08408824       0.19891800                0.11482970      0.0007129676
# 6  0.02693696       0.10264220                0.07570528      0.0004112341
# 7  0.04836926       0.12027824                0.07190897      0.0002418463
# 8  0.05799255       0.11579130                0.05779874      0.0005814329
# 9  0.06365889       0.18358817                0.11992928      0.0005456788
# 10 0.08033897       0.26303270                0.18269370      0.0007713569
# 11 0.06163146       0.16172244                0.10009097      0.0003362076
# 12 0.02825757       0.07493766                0.04668009      0.0004719014
# ...

# %%
epic_pets
# Out:
#                               All cross breeds All pure and cross breeds
# Taranaki_Per_Capita           5.966015e-02     1.620883e-01
# Tasman_Per_Capita             0.1005429020     0.2315604191
# Waikato_Per_Capita            6.056131e-02     1.539232e-01
# Wellington_Per_Capita         4.655599e-02     1.058347e-01
# West_Coast_Per_Capita         8.408824e-02     1.989180e-01
# Manawatu_Whanganui_Per_Capita 2.693696e-02     1.026422e-01
# Marlborough_Per_Capita        0.0483692648     0.1202782384
# Nelson_Per_Capita             5.799255e-02     1.157913e-01
# Otago_Per_Capita              0.0636588853     0.1835881653
# Southland_Per_Capita          8.033897e-02     2.630327e-01
# Northland_Per_Capita          0.0616314638     0.1617224376
# Auckland_Per_Capita           2.825757e-02     7.493766e-02
# Bay_Of_Plenty_Per_Capita      7.230284e-02     1.455495e-01
# Canterbury_Per_Capita         5.996670e-02     1.700687e-01
# ...
