# %%
#

# %%
library(tidyverse)
library(rvest)
library(polite)
library(magrittr) # better handling of pipes
library(purrr) # to work with lists and map functions
library(glue) # to paste strings
library(stringr)
library(plyr)
library(dplyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: xml2
#
#
# Attaching package: ‘rvest’
#
#
# The following object is masked from ‘package:purrr’:
#
#     pluck
#
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding
#
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
#
# Attaching package: ‘glue’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     collapse
#
#
# ...

# %%
condensed_dogs_renames_df <- read_csv("/Users/torieowers/Desktop/Dog_Gone/Submission Work/Notebook 3/Dogs_Per_Capita_With_Condensed_Collie_Chihuahua_and_Removed_0's.csv")
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Region = col_character()
# )
#
# See spec(...) for full column specifications.

# %%
condensed_dogs_renames_df
# Out:
#    X1 Region                        All cross breeds All pure and cross breeds
# 1   1 Auckland_Per_Capita           0.02825757       0.07493766
# 2   2 Bay_Of_Plenty_Per_Capita      0.07230284       0.14554946
# 3   3 Canterbury_Per_Capita         0.05996670       0.17006868
# 4   4 Gisbourne_Per_Capita          0.06973175       0.22326072
# 5   5 Hawkes_Bay_Per_Capita         0.05502498       0.16749727
# 6   6 Taranaki_Per_Capita           0.05966015       0.16208829
# 7   7 Tasman_Per_Capita             0.10054290       0.23156042
# 8   8 Waikato_Per_Capita            0.06056131       0.15392323
# 9   9 Wellington_Per_Capita         0.04655599       0.10583467
# 10 10 West_Coast_Per_Capita         0.08408824       0.19891797
# 11 11 Manawatu_Whanganui_Per_Capita 0.05387392       0.20528447
# 12 12 Marlborough_Per_Capita        0.09673853       0.24055648
# 13 13 Nelson_Per_Capita             0.05799255       0.11579129
# ...
