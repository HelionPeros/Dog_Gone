# %%
library(tidyr)
library(tidyverse)
library(readr)
library(skimr)
#library(readxl)
#library(read_excel)
#library(tidyxl)
#library(hablar)
#I think the commented out libraries aren't being used
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ dplyr   1.0.2
# ✔ tibble  3.0.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Error in library(read_excel): there is no package called ‘read_excel’
# Traceback:
#
# 1. library(read_excel)

# %%
getwd()
#set the working directory to the file that the region you're looking at is saved to
setwd("~/UNI SHIT/Masters/Year 1 /Semester 2 /Data Wrangling/Group Project/Pets/North Island Data")
# Out:
# [1] "/Users/andrewdoodson/UNI SHIT/Masters/Year 1 /Semester 2 /Data Wrangling/Group Project/Pets"

# %%
#Get the list of files that you're going to be reading from 
#se the path to be to the folder of the region that you're looking at
file_list <- list.files(path="~/UNI SHIT/Masters/Year 1 /Semester 2 /Data Wrangling/Group Project/Pets/North Island Data")
#change this above to be where the files are save on your computer

# %%
#initiate a blank data frame, each iteration of the loop will append the data from the given file to this variable
dataset <- data.frame()

# %%
#Specifically to get the information about pets this is the loop, 
#but can change the data[data$Topic == ""] to get it to be about other information in the csvs

for (i in 1:length(file_list)){
  data = read_csv(file_list[i])
  #e.g. if we wanted household information we would change the topic to be "Households" below
  pets_data = data[data$Topic == "Pets",]
  #and then would just change these variables names to be something sensible like house_data
  pets_data$Topic = NULL
  pets_data$NullReason = NULL
  pets_data$Source = NULL
  pets_data$ValueUnit = NULL
  pets_data$ValueLabel = NULL
    
    
  #this is specific to the pets portion, this removes the acc data
  pets_counts = pets_data[c(-1,-2,-3),]
  pets_counts
  
  
  #and if we wanted to get home ownership instead of dogs
  #we'd change the measure == "Home ownership by households"
  total_registered_dogs = pets_counts[pets_counts$Measure =="Registered dogs — Total registered dogs",]
    
  
  dataset <- rbind(dataset, total_registered_dogs) #for each iteration, bind the new data to the building dataset

}
dataset
# Out:
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#
# Parsed with column specification:
# cols(
#   `Territorial Authority` = col_character(),
#   Topic = col_character(),
#   Measure = col_character(),
#   Category = col_character(),
#   Value = col_double(),
#   ValueUnit = col_character(),
#   ValueLabel = col_character(),
#   NullReason = col_character(),
#   Date = col_character(),
#   DateLabel = col_character(),
#   Source = col_character()
# )
#      Territorial Authority Measure
# 1    Auckland              Registered dogs — Total registered dogs
# 2    Auckland              Registered dogs — Total registered dogs
# 3    Auckland              Registered dogs — Total registered dogs
# 4    Auckland              Registered dogs — Total registered dogs
# 5    Auckland              Registered dogs — Total registered dogs
# 6    Auckland              Registered dogs — Total registered dogs
# 7    Auckland              Registered dogs — Total registered dogs
# 8    Auckland              Registered dogs — Total registered dogs
# 9    Auckland              Registered dogs — Total registered dogs
#  [9] "Horowhenua.csv"            "Kaipara.csv"
# [11] "Kapiti Coast.csv"          "Kawerau.csv"
# [13] "Lower Hutt.csv"            "Manawatu.csv"
# [15] "Masterton.csv"             "Matamata-Piako.csv"
# [17] "Napier.csv"                "New Plymouth.csv"
# [19] "Opotiki.csv"               "Otorohanga.csv"
# [21] "Palmerston North.csv"      "Porirua.csv"
# [23] "Rangitikei.csv"            "Rotorua.csv"
# [25] "Ruapehu.csv"               "South Taranaki.csv"
# [27] "South Waikato.csv"         "South Wairarapa.csv"
# [29] "Stratford.csv"             "Tararua.csv"
# [31] "Taupo.csv"                 "Tauranga.csv"
# [33] "Thames-Coromandel.csv"     "Upper Hutt.csv"
# [35] "Waikato.csv"               "Waipa.csv"
# [37] "Wairoa.csv"                "Waitomo.csv"
# [39] "Wellington.csv"            "Western Bay of Plenty.csv"
# [41] "Whakatane.csv"             "Whanganui.csv"
# [43] "Whangarei.csv"

# %%
population_df = data.frame()

# %%
population_df
# Out:
# <0 x 0 matrix>

# %%
for (i in 1:length(file_list)){
  data = read.csv(file_list[i])
  #e.g. if we wanted household information we would change the topic to be "Households" below
  demo_data = data[data$Topic == "Demographics",]

  demo_data$Topic = NULL
  demo_data$NullReason = NULL
  demo_data$Source = NULL
  demo_data$ValueUnit = NULL
  demo_data$ValueLabel = NULL  

  population = demo_data[demo_data$Measure == "Population - residents at 2013 census",]  
  population_df <- rbind(population_df, population) #for each iteration, bind the new data to the building dataset
  #dataset <- rbind(dataset, population)  
}
#population_df

# %%
population_df
# Out:
#    Territorial.Authority Measure                               Category
# 1  Auckland              Population - residents at 2013 census Total people
# 2  Carterton             Population - residents at 2013 census Total people
# 3  Central Hawke's Bay   Population - residents at 2013 census Total people
# 4  Far North             Population - residents at 2013 census Total people
# 5  Gisborne              Population - residents at 2013 census Total people
# 6  Hamilton              Population - residents at 2013 census Total people
# 7  Hastings              Population - residents at 2013 census Total people
# 8  Hauraki               Population - residents at 2013 census Total people
# 9  Horowhenua            Population - residents at 2013 census Total people
# 10 Kaipara               Population - residents at 2013 census Total people
# 11 Kapiti Coast          Population - residents at 2013 census Total people
# 12 Kawerau               Population - residents at 2013 census Total people
# 13 Lower Hutt            Population - residents at 2013 census Total people
# 14 Manawatu              Population - residents at 2013 census Total people
# 15 Masterton             Population - residents at 2013 census Total people
# 16 Matamata-Piako        Population - residents at 2013 census Total people
# 17 Napier                Population - residents at 2013 census Total people
# 18 New Plymouth          Population - residents at 2013 census Total people
# 19 Opotiki               Population - residents at 2013 census Total people
# 20 Otorohanga            Population - residents at 2013 census Total people
# 21 Palmerston North      Population - residents at 2013 census Total people
# 22 Porirua               Population - residents at 2013 census Total people
# 23 Rangitikei            Population - residents at 2013 census Total people
# 24 Rotorua               Population - residents at 2013 census Total people
# 25 Ruapehu               Population - residents at 2013 census Total people
# 26 South Taranaki        Population - residents at 2013 census Total people
# 27 South Waikato         Population - residents at 2013 census Total people
# 28 South Wairarapa       Population - residents at 2013 census Total people
# 29 Stratford             Population - residents at 2013 census Total people
# 30 Tararua               Population - residents at 2013 census Total people
# 31 Taupo                 Population - residents at 2013 census Total people
# 32 Tauranga              Population - residents at 2013 census Total people
# 33 Thames-Coromandel     Population - residents at 2013 census Total people
# 34 Upper Hutt            Population - residents at 2013 census Total people
# 35 Waikato               Population - residents at 2013 census Total people
# 36 Waipa                 Population - residents at 2013 census Total people
# 37 Wairoa                Population - residents at 2013 census Total people
# 38 Waitomo               Population - residents at 2013 census Total people
# 39 Wellington            Population - residents at 2013 census Total people
# 40 Western Bay of Plenty Population - residents at 2013 census Total people
# 41 Whakatane             Population - residents at 2013 census Total people
# 42 Whanganui             Population - residents at 2013 census Total people
# 43 Whangarei             Population - residents at 2013 census Total people
#    Value   Date DateLabel
# 1  1415550 2013 Census Year
# 2     8235 2013 Census Year
# 3    12720 2013 Census Year
# 4    55734 2013 Census Year
# 5    43653 2013 Census Year
# 6   141612 2013 Census Year
# 7    73245 2013 Census Year
# 8    17811 2013 Census Year
# 9    30096 2013 Census Year
# 10   18963 2013 Census Year
# 11   49104 2013 Census Year
# 12    6363 2013 Census Year
# 13   98238 2013 Census Year
# 14   27459 2013 Census Year
# 15   23352 2013 Census Year
# 16   31536 2013 Census Year
# 17   57240 2013 Census Year
# 18   74187 2013 Census Year
# 19    8436 2013 Census Year
# 20    9138 2013 Census Year
# 21   80079 2013 Census Year
# 22   51717 2013 Census Year
# 23   14019 2013 Census Year
# 24   65280 2013 Census Year
# 25   11844 2013 Census Year
# 26   26577 2013 Census Year
# 27   22071 2013 Census Year
# 28    9528 2013 Census Year
# 29    8991 2013 Census Year
# 30   16854 2013 Census Year
# 31   32907 2013 Census Year
# 32  114789 2013 Census Year
# 33   26178 2013 Census Year
# 34   40179 2013 Census Year
# 35   63378 2013 Census Year
# 36   46668 2013 Census Year
# 37    7890 2013 Census Year
# 38    8907 2013 Census Year
# 39  190959 2013 Census Year
# 40   43692 2013 Census Year
# 41   32688 2013 Census Year
# 42   42150 2013 Census Year
# 43   76995 2013 Census Year

# %% [markdown]
# Make a function to read through and look at the home ovwnership now

# %%
homes_df  = data.frame()

# %%
for (i in 1:length(file_list)){
  data = read.csv(file_list[i])
  #e.g. if we wanted household information we would change the topic to be "Households" below
  home_data = data[data$Topic == "Households",]

  home_data$Topic = NULL
  home_data$NullReason = NULL
  home_data$Source = NULL
  home_data$ValueUnit = NULL
  home_data$ValueLabel = NULL  

  ownership = home_data[home_data$Measure == "Home ownership by households",]  
  homes_df <- rbind(homes_df, ownership) #for each iteration, bind the new data to the building dataset
}

# %%
homes_df
# Out:
#       Territorial.Authority Measure
# 225   Auckland              Home ownership by households
# 226   Auckland              Home ownership by households
# 227   Auckland              Home ownership by households
# 228   Auckland              Home ownership by households
# 221   Carterton             Home ownership by households
# 222   Carterton             Home ownership by households
# 223   Carterton             Home ownership by households
# 224   Carterton             Home ownership by households
# 220   Central Hawke's Bay   Home ownership by households
